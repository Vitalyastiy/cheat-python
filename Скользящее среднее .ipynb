# %% [markdown]
# <a href="https://colab.research.google.com/github/Vitalyastiy/cheat-python/blob/main/%D0%A1%D0%BA%D0%BE%D0%BB%D1%8C%D0%B7%D1%8F%D1%89%D0%B5%D0%B5%20%D1%81%D1%80%D0%B5%D0%B4%D0%BD%D0%B5%D0%B5%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://habr.com/ru/companies/otus/articles/728118/

# %% [markdown]
# Скользящие средние

# %%
# !pip install yfinance

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
data = [4, 5, 6, 7, 8, 9]
df = pd.DataFrame(data, columns=["Значения"])

df["Скользящее_среднее"] = df["Значения"].rolling(window=3).mean()

# %%
msft = yf.download("MSFT", start="2020-01-01", end="2023-04-08")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
msft["SMA_50"] = msft["Close"].rolling(window=50).mean()

# %%
plt.figure(figsize=(12, 6))
plt.plot(msft["Close"], label="Цена закрытия")
plt.plot(msft["SMA_50"], label="50-дневная скользящая средняя")
plt.title("Динамика изменения цены на акции Microsoft")
plt.xlabel("Дата")
plt.ylabel("Цена")
plt.legend()
plt.show()

# %%
msft
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-02  158.779999  160.729996  158.330002  160.619995  155.422073
# 2020-01-03  158.320007  159.949997  158.059998  158.619995  153.486801
# 2020-01-06  157.080002  159.100006  156.509995  159.029999  153.883484
# 2020-01-07  159.320007  159.669998  157.320007  157.580002  152.480438
# 2020-01-08  158.929993  160.800003  157.949997  160.089996  154.909225
# ...                ...         ...         ...         ...         ...
# 2023-03-31  283.730011  289.269989  283.000000  288.299988  287.671112
# 2023-04-03  286.519989  288.269989  283.950012  287.230011  286.603485
# 2023-04-04  287.230011  290.450012  285.670013  287.179993  286.553558
# 2023-04-05  285.850006  287.149994  282.920013  284.339996  283.719757
# 2023-04-06  283.209991  292.079987  282.029999  291.600006  290.963928
#
#               Volume      SMA_50
# Date
# 2020-01-02  22622100         NaN
# 2020-01-03  21116200         NaN
# ...

# %%
df
# Out:
#    Значения  Скользящее_среднее
# 0         4                 NaN
# 1         5                 NaN
# 2         6                 NaN
# 3         7                 NaN
# 4         8                 6.0
# 5         9                 7.0
